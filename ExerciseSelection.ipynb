# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("megaGymDataset.csv")

# %%
levels=df["Level"].unique()
Bodyparts=df["BodyPart"].unique()
Bodyparts
# Out:
# array(['Abdominals', 'Adductors', 'Abductors', 'Biceps', 'Calves',
#        'Chest', 'Forearms', 'Glutes', 'Hamstrings', 'Lats', 'Lower Back',
#        'Middle Back', 'Traps', 'Neck', 'Quadriceps', 'Shoulders',
#        'Triceps'], dtype=object)

# %%
level=input("Choose Your Level:1)Beginner, 2)Intermediate, 3)Expert")
muscle_to_train=input("Which muscle will you train today?")
# Out:
# Choose Your Level:1)Beginner, 2)Intermediate, 3)Expert Beginner
# Which muscle will you train today? Shoulders

# %%
no_of_exercises=input("How many exercises you wish to do?")
# Out:
# How many exercises you wish to do? 7

# %%
no_of_exercises
# Out:
# '7'

# %%
exercises=df[df["BodyPart"]==muscle_to_train]

if(level=="Beginner"):
    exercises=exercises[exercises["Level"].isin(["Beginner"])]
elif(level=="Intermediate"):
    exercises=exercises[exercises["Level"].isin(["Beginner","Intermediate"])]
else:
    exercises=exercises[exercises["Level"].isin(["Beginner","Intermediate","Expert"])]


    





    

exercises
# Out:
#       Unnamed: 0                                          Title  \
# 2427        2427                    Internal Rotation with Band
# 2429        2429                        Back Flyes - With Bands
# 2430        2430                     Lateral Raise - With Bands
# 2431        2431                    Shoulder Press - With Bands
# 2432        2432                    External Rotation with Band
# 2452        2452     Snatch-Grip Behind-The-Neck Overhead Press
# 2457        2457                         Bradford/Rocky Presses
# 2465        2465                                  Rack Delivery
# 2466        2466                   Smith Incline Shoulder Raise
# 2467        2467                             Tall Muscle Snatch
# 2468        2468                           Axle Clean And Press
# 2469        2469                                   Jerk Balance
# 2489        2489              Two-Arm Kettlebell Military Press
# 2490        2490                   Alternating Kettlebell Press
# ...

# %%
sorted_exercises = exercises.sort_values(by='Rating', ascending=False)
sorted_exercises.head(int(no_of_exercises))
# Out:
#       Unnamed: 0                                       Title Desc        Type  \
# 2531        2531                              Power Partials  NaN    Strength
# 2452        2452  Snatch-Grip Behind-The-Neck Overhead Press  NaN    Strength
# 2489        2489           Two-Arm Kettlebell Military Press  NaN    Strength
# 2683        2683                     Cable Internal Rotation  NaN    Strength
# 2490        2490                Alternating Kettlebell Press  NaN    Strength
# 2549        2549                              Dumbbell Raise  NaN    Strength
# 2763        2763                             Side Wrist Pull  NaN  Stretching
#
#        BodyPart    Equipment     Level  Rating RatingDesc
# 2531  Shoulders     Dumbbell  Beginner     9.1    Average
# 2452  Shoulders      Barbell  Beginner     9.0    Average
# 2489  Shoulders  Kettlebells  Beginner     8.7    Average
# 2683  Shoulders        Cable  Beginner     8.6    Average
# ...

# %%
# Out:
#   Cell In[39], line 1
#     for
#        ^
# SyntaxError: invalid syntax
